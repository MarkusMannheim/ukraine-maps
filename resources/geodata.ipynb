# %%
import geopandas as gpd

geodata = gpd.read_file("world-administrative-boundaries.geojson")
geodata = geodata[geodata.iso3 == "UKR"]
geodata = geodata[["name", "geometry"]]
geodata.to_file("ukr.geojson", driver="GeoJSON")
geodata.plot(figsize=(15, 15))
# Out:
# <AxesSubplot:>
